# %%
# !pip install crewai PyPDF2 openai

# %%
# !pip install --upgrade PyPDF2 crewai gradio

# %%
# !pip install ratelimit validate-email-address bleach python-dotenv

# %%
import os
import sys
import traceback
from crewai import Agent, Task, Crew, Process
import PyPDF2
import re
import smtplib
from email.mime.text import MIMEText
from email.mime.multipart import MIMEMultipart
import json
import gradio as gr

def extract_text_from_pdf(pdf_file):
    pdf_reader = PyPDF2.PdfReader(pdf_file)
    text = ""
    for page in pdf_reader.pages:
        text += page.extract_text()
    return text

def extract_email(text):
    email_pattern = r'\b[A-Za-z0-9._%+-]+@[A-Za-z0-9.-]+\.[A-Z|a-z]{2,}\b'
    emails = re.findall(email_pattern, text)
    return emails[0] if emails else None

class DocumentAnalyzerCrew:
    def __init__(self, document_text, reference_data, api_key):
        os.environ["OPENAI_API_KEY"] = api_key
        
        # Store agent task results
        self.agent_results = {}
        
        self.text_extraction_agent = Agent(
            role="Text Extraction Specialist",
            goal="Extract precise key information from documents",
            backstory="An expert in parsing complex documents and identifying critical information with high accuracy",
            verbose=True,
            allow_delegation=False
        )

        self.comparison_agent = Agent(
            role="Document Comparison Expert",
            goal="Compare extracted document data against reference standards",
            backstory="A meticulous analyst specializing in identifying discrepancies between document contents and expected standards",
            verbose=True,
            allow_delegation=False
        )

        self.reporting_agent = Agent(
            role="Detailed Report Generator",
            goal="Create comprehensive and clear analysis reports",
            backstory="A skilled communicator who transforms technical findings into clear, actionable insights",
            verbose=True,
            allow_delegation=False
        )

        self.document_text = document_text
        self.reference_data = reference_data

    def analyze_document(self):
        # Text Extraction Task
        extraction_task = Task(
            description=f"""
            Carefully extract key information from the following document text.
            Focus on finding these specific items: {', '.join(self.reference_data.keys())}

            Document Text:
            {self.document_text[:2000]}
            """,
            agent=self.text_extraction_agent,
            expected_output="A detailed dictionary of extracted key-value pairs from the document"
        )

        # Comparison Task
        comparison_task = Task(
            description=f"""
            Compare the extracted data against these reference standards:
            {json.dumps(self.reference_data, indent=2)}

            Identify any mismatches, missing information, or potential discrepancies.
            Provide a detailed explanation for each difference found.
            """,
            agent=self.comparison_agent,
            expected_output="A comprehensive list of mismatches and detailed analysis"
        )

        # Reporting Task
        reporting_task = Task(
            description="""
            Generate a comprehensive report summarizing the document analysis.
            Include:
            1. Extracted key information
            2. Comparison results
            3. Detailed insights and recommendations
            """,
            agent=self.reporting_agent,
            expected_output="A detailed, structured report with all analysis findings"
        )

        # Create Crew with modified output capturing
        crew = Crew(
            agents=[
                self.text_extraction_agent,
                self.comparison_agent,
                self.reporting_agent
            ],
            tasks=[
                extraction_task,
                comparison_task,
                reporting_task
            ],
            verbose=True  # Enable verbose output
        )

        try:
            # Kick off the crew and capture detailed results
            result = crew.kickoff()
            
            # Collect and structure agent results
            full_report = "📋 Detailed Document Analysis Report\n\n"
            
            # Text Extraction Agent Results
            full_report += "🔍 Text Extraction Agent:\n"
            full_report += str(extraction_task.output) + "\n\n"
            
            # Comparison Agent Results
            full_report += "🔬 Document Comparison Agent:\n"
            full_report += str(comparison_task.output) + "\n\n"
            
            # Reporting Agent Final Result
            full_report += "📝 Final Analysis Report:\n"
            full_report += str(result) + "\n"
            
            return full_report
        except Exception as e:
            return f"Analysis Error: {str(e)}\n{traceback.format_exc()}"

def send_email(recipient_email, analysis_result):
    sender_email = os.getenv("SMTP_EMAIL")
    sender_password = os.getenv("SMTP_PASSWORD")

    if not all([sender_email, sender_password]):
        return False, "Email credentials not found in environment variables"

    message = MIMEMultipart()
    message["From"] = sender_email
    message["To"] = recipient_email
    message["Subject"] = "Document Analysis Report"

    message.attach(MIMEText(analysis_result, "plain"))

    try:
        with smtplib.SMTP_SSL("smtp.gmail.com", 465) as server:
            server.login(sender_email, sender_password)
            server.sendmail(sender_email, recipient_email, message.as_string())
        return True, "Email sent successfully"
    except Exception as e:
        return False, f"Failed to send email: {str(e)}"

def process_document(api_key, pdf_file, send_email_flag):
    # Default reference data
    reference_data = {
        "limitation of liability": "30 days",
        "owner expiry date": "30 days",
        "notice period": "30 days",
        "agreement duration": "12 months",
        "payment terms": "30 days",
        "confidentiality period": "3 years",
        "insurance coverage": "$1,000,000",
        "maximum monthly hours": "120"
    }

    try:
        # Extract text from PDF
        doc_text = extract_text_from_pdf(pdf_file)

        # Extract email if present
        user_email = extract_email(doc_text)

        # Initialize document analyzer
        document_analyzer = DocumentAnalyzerCrew(doc_text, reference_data, api_key)

        # Perform document analysis
        analysis_result = document_analyzer.analyze_document()

        # Optional email sending
        email_status = ""
        if send_email_flag and user_email:
            success, message = send_email(user_email, analysis_result)
            email_status = f"\n\nEmail Status: {message}"

        return analysis_result + email_status

    except Exception as e:
        return f"An error occurred: {str(e)}\n{traceback.format_exc()}"

def launch_gradio_interface():
    # Gradio Interface
    with gr.Blocks(title="Document Analysis Workflow") as demo:
        gr.Markdown("# 📄 Document Analysis Workflow")

        with gr.Row():
            with gr.Column():
                api_key_input = gr.Textbox(
                    label="OpenAI API Key",
                    type="password",
                    placeholder="Enter your OpenAI API key"
                )
                pdf_input = gr.File(
                    label="Upload PDF Document",
                    file_types=[".pdf"]
                )
                send_email_checkbox = gr.Checkbox(
                    label="Send analysis via email",
                    value=False
                )
                analyze_btn = gr.Button("Analyze Document", variant="primary")

            with gr.Column():
                output = gr.Textbox(
                    label="Analysis Result",
                    interactive=False
                )

        # Action
        analyze_btn.click(
            fn=process_document,
            inputs=[api_key_input, pdf_input, send_email_checkbox],
            outputs=output
        )

    return demo

# Launch the Gradio interface
demo = launch_gradio_interface()
demo.launch(debug=True)
# Out:
# * Running on local URL:  http://127.0.0.1:7860
#
# To create a public link, set `share=True` in `launch()`.
# <div><iframe src="http://127.0.0.1:7860/" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>
# # Agent: Text Extraction Specialist
# ## Task:
#             Carefully extract key information from the following document text.
#             Focus on finding these specific items: limitation of liability, owner expiry date, notice period, agreement duration, payment terms, confidentiality period, insurance coverage, maximum monthly hours
#
#             Document Text:
#             CONSULTING SERVICES AGREEMENT
#
# This Consulting Services Agreement ("Agreement") is made effective as of 15/01/2024, by and between:
#
# ABC Technologies Inc.
# 123 Tech Park Avenue
# Silicon Valley, CA 94025
#
# Contact: john.doe@abctech.com
#
# and
#
# XYZ Consulting LLC ("Consultant")
# 456 Business Plaza
# New York, NY 10001
#
# KEY TERMS AND CONDITIONS:
#
# 1. Agreement Duration:
#    Start Date: 15/01/2024
#    End Date: 14/01/2025
#
# 2. Service Scope:
#    - Technical consulting
#    - Project management
#    - Strategic advisory
#
# 3. Financial Terms:
#    - Rate: $150 per hour     - Payment terms: Net 45 days
#    - Maximum monthly hours: 160
#
# 4. Limitation of Liability:
#    The Consultant's liability shall be limited to 45 days of fees paid.
#
# 5. Notice Period:
#    Termination notice period: 60 days
#
# 6. Data Protection:
#    Compliance with GDPR and local data protection laws
#
# 7. Confidentiality Period:
#    5 years from the date of disclosure
#
# 8. Insurance Coverage:
#    Professional liability insurance: $2,000,000
#
# 9. Owner Expiry Date:
#    45 days from the last service date
#
# For any queries, please contact: support@abctech.com
#
#
#
# # Agent: Text Extraction Specialist
# ## Final Answer:
# {
#   "Agreement Duration": {
#     "Start Date": "15/01/2024",
#     "End Date": "14/01/2025"
#   },
#   "Payment Terms": "Net 45 days",
#   "Maximum Monthly Hours": 160,
#   "Limitation of Liability": "The Consultant's liability shall be limited to 45 days of fees paid.",
#   "Notice Period": "Termination notice period: 60 days",
#   "Confidentiality Period": "5 years from the date of disclosure",
#   "Insurance Coverage": "Professional liability insurance: $2,000,000",
#   "Owner Expiry Date": "45 days from the last service date"
# }
#
#
# # Agent: Document Comparison Expert
# ## Task:
#             Compare the extracted data against these reference standards:
#             {
#   "limitation of liability": "30 days",
#   "owner expiry date": "30 days",
#   "notice period": "30 days",
#   "agreement duration": "12 months",
#   "payment terms": "30 days",
#   "confidentiality period": "3 years",
#   "insurance coverage": "$1,000,000",
#   "maximum monthly hours": "120"
# }
#
#             Identify any mismatches, missing information, or potential discrepancies.
#             Provide a detailed explanation for each difference found.
#
#
#
# # Agent: Document Comparison Expert
# ## Final Answer:
# Upon comparison of the extracted data against the reference standards, I have identified several mismatches, missing information, and potential discrepancies. Below is a comprehensive list of discrepancies found:
#
# 1. **Limitation of Liability**
#    - **Extracted Data:** "The Consultant's liability shall be limited to 45 days of fees paid."
#    - **Reference Standard:** "30 days"
#    - **Analysis:** There is a mismatch of 15 days. The extracted limitation extends the liability period beyond the standard, which could expose the owner to greater risk and may need to be revised to align with the reference standard.
#
# 2. **Owner Expiry Date**
#    - **Extracted Data:** "45 days from the last service date"
#    - **Reference Standard:** "30 days"
#    - **Analysis:** This presents another discrepancy of 15 days, whereby the owner expiry date is longer than stipulated in the reference. Again, this could have implications for the duration of services and liability.
#
# 3. **Notice Period**
#    - **Extracted Data:** "Termination notice period: 60 days"
#    - **Reference Standard:** "30 days"
#    - **Analysis:** There is a significant discrepancy of 30 days. The extracted period is double what is referred to in the standard. This could complicate the termination process.
#
# 4. **Agreement Duration**
#    - **Extracted Data:** "Start Date: 15/01/2024, End Date: 14/01/2025" (which amounts to 12 months)
#    - **Reference Standard:** "12 months"
#    - **Analysis:** This item matches the reference standard correctly. The agreement duration is consistent and adheres to the needed timeframe.
#
# 5. **Payment Terms**
#    - **Extracted Data:** "Net 45 days"
#    - **Reference Standard:** "30 days"
#    - **Analysis:** There is a mismatch of 15 days which indicates that payments are expected to be made later than the reference standard stipulates. This might affect cash flow and financial planning.
#
# 6. **Confidentiality Period**
#    - **Extracted Data:** "5 years from the date of disclosure"
#    - **Reference Standard:** "3 years"
#    - **Analysis:** This discrepancy of 2 years indicates that the extracted data extends the confidentiality commitment beyond the reference standard, which could affect the management of sensitive information.
#
# 7. **Insurance Coverage**
#    - **Extracted Data:** "Professional liability insurance: $2,000,000"
#    - **Reference Standard:** "$1,000,000"
#    - **Analysis:** The coverage in the extracted data exceeds the reference standard by $1,000,000. While this may provide additional protection, it could affect costs and liability arrangements.
#
# 8. **Maximum Monthly Hours**
#    - **Extracted Data:** "160"
#    - **Reference Standard:** "120"
#    - **Analysis:** There is a mismatch of 40 hours, which indicates an allowance for more work than the reference standard permits, potentially leading to overcommitment or resource allocation issues.
#
# In summary, the key discrepancies identified include mismatched duration and conditions for liability, owner expiry, notice period, payment terms, confidentiality period, insurance coverage, and maximum monthly hours. Each of these areas presents a need for potential revision to align with established reference standards, ensuring clearer expectations and obligations moving forward.
#
#
# # Agent: Detailed Report Generator
# ## Task:
#             Generate a comprehensive report summarizing the document analysis.
#             Include:
#             1. Extracted key information
#             2. Comparison results
#             3. Detailed insights and recommendations
#
#
#
# # Agent: Detailed Report Generator
# ## Final Answer:
# **Comprehensive Analysis Report on Document Discrepancies**
#
# **1. Extracted Key Information:**
# The analyses performed on the extracted data against reference standards have revealed numerous discrepancies that must be addressed. Below is the summary of the key information extracted from the document under review:
#
# - **Limitation of Liability:**
#   - Extracted Data: "The Consultant's liability shall be limited to 45 days of fees paid."
#   - Reference Standard: "30 days"
#
# - **Owner Expiry Date:**
#   - Extracted Data: "45 days from the last service date."
#   - Reference Standard: "30 days"
#
# - **Notice Period for Termination:**
#   - Extracted Data: "Termination notice period: 60 days."
#   - Reference Standard: "30 days"
#
# - **Agreement Duration:**
#   - Extracted Data: "Start Date: 15/01/2024, End Date: 14/01/2025."
#   - Reference Standard: "12 months" (consistent)
#
# - **Payment Terms:**
#   - Extracted Data: "Net 45 days."
#   - Reference Standard: "30 days"
#
# - **Confidentiality Period:**
#   - Extracted Data: "5 years from the date of disclosure."
#   - Reference Standard: "3 years"
#
# - **Insurance Coverage:**
#   - Extracted Data: "Professional liability insurance: $2,000,000."
#   - Reference Standard: "$1,000,000"
#
# - **Maximum Monthly Hours:**
#   - Extracted Data: "160."
#   - Reference Standard: "120"
#
# **2. Comparison Results:**
# The comparison between the extracted data and the reference standards indicates the following discrepancies:
#
# - **Limitation of Liability:** A discrepancy of **15 days** greater than standard.
# - **Owner Expiry Date:** A discrepancy of **15 days** longer than standard.
# - **Notice Period:** A significant discrepancy of **30 days** longer than standard.
# - **Agreement Duration:** Data matches reference, **12 months** confirmed.
# - **Payment Terms:** A discrepancy of **15 days** longer expected.
# - **Confidentiality Period:** A discrepancy of **2 years** longer than standard.
# - **Insurance Coverage:** An excess of **$1,000,000** compared to standard.
# - **Maximum Monthly Hours:** An increase of **40 hours** above the standard.
#
# **3. Detailed Insights and Recommendations:**
# The analysis leads to the following insights, which highlight both potential risks and necessary adjustments:
#
# - **Limitation of Liability**: The increased liability period could expose the owner to financial risks. **Recommendation**: Amend the clause to align with the reference standard of 30 days.
#
# - **Owner Expiry Date**: The longer expiration period could complicate the contract's execution and oversight. **Recommendation**: Adjust to 30 days to remain consistent with standard practices.
#
# - **Notice Period**: The extended termination notice may lead to complications in project management. **Recommendation**: Shorten to 30 days to provide clarity and agility in service termination.
#
# - **Agreement Duration**: The 12-month term aligns with expectations, thereby confirming compliance. **Recommendation**: No changes are necessary here.
#
# - **Payment Terms**: The extended payment timeframe of 45 days could lead to cash flow issues. **Recommendation**: Realign payment terms to 30 days to facilitate better financial planning.
#
# - **Confidentiality Period**: A 5-year confidentiality commitment may be excessive and impractical. **Recommendation**: Revise to 3 years in line with industry standards to encourage more efficient handling of sensitive information.
#
# - **Insurance Coverage**: Higher coverage may increase costs without a proportional benefit. **Recommendation**: Consider adjusting to a more standard coverage of $1,000,000 unless justified by specific project risks.
#
# - **Maximum Monthly Hours**: Allowing 160 hours may lead to challenges in resource management. **Recommendation**: Cap at 120 hours to prevent resource overcommitment and ensure operational efficiency.
#
# ---
#
# This report outlines the various discrepancies found in the key document and provides comprehensive recommendations for each to ensure alignment with established reference standards, ultimately leading to clearer expectations and better management moving forward.
#
#
# Keyboard interruption in main thread... closing server.
